# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
pd.set_option('display.max_rows',85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv',index_col='Column')

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
df.loc[1:10,'Hobbyist':'Student']
# Out:
#    Hobbyist                 OpenSourcer  \
# 1        No     Less than once per year
# 2       Yes                       Never
# 3        No                       Never
# 4       Yes  Once a month or more often
# 5       Yes                       Never
# 6        No                       Never
# 7       Yes     Less than once per year
# 8       Yes  Once a month or more often
# 9       Yes  Once a month or more often
# 10      Yes  Once a month or more often
#
#                                            OpenSource  \
# 1   The quality of OSS and closed source software ...
# 2   The quality of OSS and closed source software ...
# 3   The quality of OSS and closed source software ...
# 4   OSS is, on average, of HIGHER quality than pro...
# 5   The quality of OSS and closed source software ...
# 6   The quality of OSS and closed source software ...
# 7   OSS is, on average, of HIGHER quality than pro...
# 8   The quality of OSS and closed source software ...
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Man                                                            77919
# Woman                                                           6344
# Non-binary, genderqueer, or gender non-conforming                597
# Man;Non-binary, genderqueer, or gender non-conforming            181
# Woman;Non-binary, genderqueer, or gender non-conforming          163
# Woman;Man                                                        132
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       70
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Papua New Guinea                        1
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Sao Tome and Principe                   1
# Chad                                    1
# Name: count, Length: 179, dtype: int64

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
df.head(1)
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country Student  \
# 0  Not employed, and not looking for work  United Kingdom      No
#
#                      EdLevel UndergradMajor  ...  \
# 0  Primary/elementary school            NaN  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
#
#                  Sexuality Ethnicity Dependents           SurveyLength  \
# 0  Straight / Heterosexual       NaN         No  Appropriate in length
#
#                    SurveyEase
# 0  Neither easy nor difficult
#
# ...

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
df['ConvertedComp'].max()
# Out:
# np.float64(2000000.0)

# %%
df['ConvertedComp']>=100000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: ConvertedComp, Length: 88883, dtype: bool

# %%
df[df['ConvertedComp']>=100000]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 15             16                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# 25             26                     I am a developer by profession      Yes
# 28             29                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88321       88874                     I am a developer by profession      Yes
# 88323       88876                     I am a developer by profession      Yes
# 88324       88877                     I am a developer by profession      Yes
# 88325       88878                     I am a developer by profession      Yes
# 88329       88882                     I am a developer by profession      Yes
#
# ...

# %%
df['Country']=='Nigeria'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: Country, Length: 88883, dtype: bool

# %%
df[df['Country']== 'Nigeria']
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 203           205  I am not primarily a developer, but I write co...      Yes
# 346           348                     I am a developer by profession      Yes
# 363           365                        I code primarily as a hobby      Yes
# 685           688                     I am a developer by profession      Yes
# 882           885                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88261       88812                     I am a developer by profession      Yes
# 88269       88821             I am a student who is learning to code       No
# 88807       76960                                                NaN       No
# 88823       79616                                                NaN       No
# 88867       86806                                                NaN      Yes
#
# ...

# %%
df[(df['ConvertedComp']>=100000) & (df['Country']== 'Nigeria')]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 31034       31220  I am a developer by profession      Yes
# 45670       45962  I am a developer by profession      Yes
# 71429       71883  I am a developer by profession      Yes
#
#                    OpenSourcer  \
# 31034                    Never
# 45670  Less than once per year
# 71429                    Never
#
#                                               OpenSource  \
# 31034  The quality of OSS and closed source software ...
# 45670  The quality of OSS and closed source software ...
# 71429  The quality of OSS and closed source software ...
#
#                                               Employment  Country Student  \
# 31034  Independent contractor, freelancer, or self-em...  Nigeria      No
# 45670                                 Employed full-time  Nigeria      No
# 71429                                 Employed full-time  Nigeria      No
#
#                                            EdLevel  \
# ...

# %%
df['Student'].value_counts()
# Out:
# Student
# No                65816
# Yes, full-time    15769
# Yes, part-time     5429
# Name: count, dtype: int64

# %%
df['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              39134
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           19569
# Some college/university study without earning a degree                                10502
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8642
# Associate degree                                                                       2938
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              2432
# Primary/elementary school                                                              1422
# Professional degree (JD, MD, etc.)                                                     1198
# I never completed any formal education                                                  553
# Name: count, dtype: int64

# %%
flas = df['ConvertedComp']>= 100000
df.loc[flas,['Hobbyist','Employment','Country','ConvertedComp']]
# Out:
#       Hobbyist          Employment         Country  ConvertedComp
# 5          Yes  Employed full-time          Canada       366420.0
# 15         Yes  Employed full-time  United Kingdom       455352.0
# 21         Yes  Employed full-time   United States       103000.0
# 25         Yes  Employed full-time   United States       114000.0
# 28         Yes  Employed full-time   United States       100000.0
# ...        ...                 ...             ...            ...
# 88321      Yes  Employed full-time   United States      2000000.0
# 88323      Yes  Employed full-time   United States       180000.0
# 88324      Yes  Employed full-time   United States      2000000.0
# 88325      Yes  Employed full-time   United States       130000.0
# 88329      Yes  Employed full-time     Netherlands       588012.0
#
# [14257 rows x 4 columns]

# %%
schema_df.loc['LanguageWorkedWith','QuestionText']
# Out:
# 'Which of the following programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year?  (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
df['LanguageWorkedWith'].str.contains('SQL')
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 88878    False
# 88879      NaN
# 88880      NaN
# 88881      NaN
# 88882     True
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
df[df['LanguageWorkedWith'].str.contains('SQL',na=False)]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88854       84539                                                NaN      Yes
# 88857       85396                                                NaN       No
# 88871       87386                                                NaN      Yes
# 88872       87739                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
# ...

# %%
sql = df['LanguageWorkedWith'].str.contains('SQL',na=False)
df.loc[sql,'LanguageWorkedWith']
# Out:
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 5                                               Java;R;SQL
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 8        Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88857             Bash/Shell/PowerShell;HTML/CSS;PHP;R;SQL
# 88871    Assembly;Bash/Shell/PowerShell;C;C#;HTML/CSS;J...
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 47544, dtype: object

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'},inplace=True)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df['SalaryUSD']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['SalaryUSD'].mean()
# Out:
# np.float64(127110.73842323056)

# %%
sns.boxplot(data=df,x='SalaryUSD')
# Out:
# <Axes: xlabel='SalaryUSD'>

# %%
sns.boxplot(data=df,x='YearsCode')
# Out:
# <Axes: xlabel='YearsCode'>

# %%
df.describe()
# Out:
#          Respondent     CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04  5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11  1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13  2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00  0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04  2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04  5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05  1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16  2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df1=df.groupby(['Country'])['SalaryUSD'].mean().loc[['Nigeria','Ghana','Egypt','Morocco','South Africa']]
df1
# Out:
# Country
# Nigeria         16828.869347
# Ghana           16520.181818
# Egypt           13923.026490
# Morocco         20958.219512
# South Africa    63550.602871
# Name: SalaryUSD, dtype: float64

# %%
ax=df1.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.title('Mean Salary for 5African Nation')                                     
plt.ylabel('Mean Salary')
plt.show()

# %%
df1.index
# Out:
# Index(['Nigeria', 'Ghana', 'Egypt', 'Morocco', 'South Africa'], dtype='object', name='Country')

# %%
df1.values
# Out:
# array([16828.86934673, 16520.18181818, 13923.02649007, 20958.2195122 ,
#        63550.60287081])

# %%
sns.barplot(x=df1.index,y=df1.values)
plt.show()

# %%
df.groupby(['Country'])['SalaryUSD'].mean().sort_values(ascending=False).head(20).round(2)
# Out:
# Country
# Liechtenstein         811188.00
# San Marino            301788.00
# Ireland               250342.24
# United States         249546.25
# Swaziland             242607.50
# Timor-Leste           229500.00
# Qatar                 224692.67
# Republic of Korea     204341.12
# Norway                182298.94
# Switzerland           172675.60
# Australia             171541.12
# United Kingdom        166182.50
# Andorra               160931.00
# Kuwait                153294.00
# New Zealand           151681.80
# Luxembourg            144603.64
# Canada                134018.56
# Singapore             120621.51
# Denmark               113769.55
# Hong Kong (S.A.R.)    111738.33
# Name: SalaryUSD, dtype: float64

# %%
df2=df.groupby(['Country'])['SalaryUSD'].mean().sort_values(ascending=False).head(20).round(2)
df2
# Out:
# Country
# Liechtenstein         811188.00
# San Marino            301788.00
# Ireland               250342.24
# United States         249546.25
# Swaziland             242607.50
# Timor-Leste           229500.00
# Qatar                 224692.67
# Republic of Korea     204341.12
# Norway                182298.94
# Switzerland           172675.60
# Australia             171541.12
# United Kingdom        166182.50
# Andorra               160931.00
# Kuwait                153294.00
# New Zealand           151681.80
# Luxembourg            144603.64
# Canada                134018.56
# Singapore             120621.51
# Denmark               113769.55
# Hong Kong (S.A.R.)    111738.33
# Name: SalaryUSD, dtype: float64

# %%
gx=sns.barplot(x=df2.index,y=df2.values)
gx.bar_label(gx.containers[0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gx=sns.barplot(x=df2.index,y=df2.values)
gx.bar_label(gx.containers[0],rotation=90)
plt.xticks(rotation='vertical')                                       
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(df,x='Employment',bins=10)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.groupby(['EdLevel'])['SalaryUSD'].value_counts()
# Out:
# EdLevel                                                 SalaryUSD
# Associate degree                                        2000000.0    47
#                                                         1000000.0    23
#                                                         60000.0      21
#                                                         80000.0      20
#                                                         70000.0      19
#                                                                      ..
# Some college/university study without earning a degree  1668000.0     1
#                                                         1680000.0     1
#                                                         1740000.0     1
#                                                         1752000.0     1
#                                                         1965600.0     1
# Name: count, Length: 16696, dtype: int64

# %%
df.groupby(['EdLevel'])['SalaryUSD'].value_counts().loc['Master’s degree (MA, MS, M.Eng., MBA, etc.)']
# Out:
# SalaryUSD
# 57287.0      162
# 68745.0      143
# 1000000.0    139
# 54996.0      123
# 45830.0      118
#             ...
# 1836000.0      1
# 1860000.0      1
# 1872000.0      1
# 1920000.0      1
# 1980000.0      1
# Name: count, Length: 3927, dtype: int64
