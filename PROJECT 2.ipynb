# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cd = pd.read_csv('Customer Call List2.csv')
cd
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
cd.shape
# Out:
# (21, 8)

# %%
cd.duplicated().sum()
# Out:
# np.int64(1)

# %%
cd.drop_duplicates(inplace=True)

# %%
cd.duplicated().sum()
# Out:
# np.int64(0)

# %%
cd['Last_Name']
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
cd['Last_Name'].str.lstrip('/')
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
cd['Last_Name'].str.rstrip('_')
# Out:
# 0        Baggins
# 1          Nadir
# 2         /White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11     ...Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
cd['Last_Name'].str.strip('/,...,_')
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
cd['Last_Name'] = cd['Last_Name'].str.strip('/,...,_')

# %%
cd['Last_Name']
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
cd.dropna(axis='index',how='any',subset='Phone_Number')
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# 18        1019      Creed      Braton           N/a
# ...

# %%
cd.replace('N/a',np.nan,inplace=True)

# %%
cd.dropna(axis='index',how='any',subset='Phone_Number',inplace=True)

# %%
cd
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 7         1008   Sherlock      Holmes  876|678|3469
# 9         1010      Peter      Parker  123-545-5421
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# 19        1020     Anakin   Skywalker  876|678|3469
#
# ...

# %%
cd['Phone_Number'].str.replace('[^a-zA-Z0-9]',"",regex=True)
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 7     8766783469
# 9     1235455421
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
cd['Phone_Number'] = cd['Phone_Number'].str.replace('[^a-zA-Z0-9]',"",regex=True)

# %%
cd['Phone_Number']
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 7     8766783469
# 9     1235455421
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
cd['Address']
# Out:
# 0                     123 Shire Lane, Shire
# 1                       93 West Main Street
# 2                        298 Drugs Driveway
# 3     980 Paper Avenue, Pennsylvania, 18503
# 4                          123 Dragons Road
# 5                          768 City Parkway
# 7                             98 Clue Drive
# 9                25th Main Street, New York
# 11                     2394 Hogwarts Avenue
# 12                         2039 Main Street
# 13                         343 City Parkway
# 14                            214 HR Avenue
# 15                     2395 Hogwarts Avenue
# 16           121 Paper Avenue, Pennsylvania
# 17                          3498 Super Lane
# 19              910 Tatooine Road, Tatooine
# Name: Address, dtype: object

# %%
cd['Address'].str.split(',')
# Out:
# 0                      [123 Shire Lane,  Shire]
# 1                         [93 West Main Street]
# 2                          [298 Drugs Driveway]
# 3     [980 Paper Avenue,  Pennsylvania,  18503]
# 4                            [123 Dragons Road]
# 5                            [768 City Parkway]
# 7                               [98 Clue Drive]
# 9                 [25th Main Street,  New York]
# 11                       [2394 Hogwarts Avenue]
# 12                           [2039 Main Street]
# 13                           [343 City Parkway]
# 14                              [214 HR Avenue]
# 15                       [2395 Hogwarts Avenue]
# 16            [121 Paper Avenue,  Pennsylvania]
# 17                            [3498 Super Lane]
# 19               [910 Tatooine Road,  Tatooine]
# Name: Address, dtype: object

# %%
cd['Address'].str.split(',').str.get(0)
# Out:
# 0           123 Shire Lane
# 1      93 West Main Street
# 2       298 Drugs Driveway
# 3         980 Paper Avenue
# 4         123 Dragons Road
# 5         768 City Parkway
# 7            98 Clue Drive
# 9         25th Main Street
# 11    2394 Hogwarts Avenue
# 12        2039 Main Street
# 13        343 City Parkway
# 14           214 HR Avenue
# 15    2395 Hogwarts Avenue
# 16        121 Paper Avenue
# 17         3498 Super Lane
# 19       910 Tatooine Road
# Name: Address, dtype: object

# %%
cd['Address'].str.split(',').str.get(1)
# Out:
# 0             Shire
# 1               NaN
# 2               NaN
# 3      Pennsylvania
# 4               NaN
# 5               NaN
# 7               NaN
# 9          New York
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16     Pennsylvania
# 17              NaN
# 19         Tatooine
# Name: Address, dtype: object

# %%
cd['Address'].str.split(',',n=2)
# Out:
# 0                      [123 Shire Lane,  Shire]
# 1                         [93 West Main Street]
# 2                          [298 Drugs Driveway]
# 3     [980 Paper Avenue,  Pennsylvania,  18503]
# 4                            [123 Dragons Road]
# 5                            [768 City Parkway]
# 7                               [98 Clue Drive]
# 9                 [25th Main Street,  New York]
# 11                       [2394 Hogwarts Avenue]
# 12                           [2039 Main Street]
# 13                           [343 City Parkway]
# 14                              [214 HR Avenue]
# 15                       [2395 Hogwarts Avenue]
# 16            [121 Paper Avenue,  Pennsylvania]
# 17                            [3498 Super Lane]
# 19               [910 Tatooine Road,  Tatooine]
# Name: Address, dtype: object

# %%
cd[['street_Address','State','Zip_Code']]=cd['Address'].str.split(',',n=2,expand=True)

# %%
cd
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 7         1008   Sherlock      Holmes   8766783469
# 9         1010      Peter      Parker   1235455421
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent   7066950392
# 19        1020     Anakin   Skywalker   8766783469
#
#                                   Address Paying Customer Do_Not_Contact  \
# ...

# %%
cd['Paying Customer']=cd['Paying Customer'].str.replace('Yes','Y').str.replace('No','N')
cd['Paying Customer']
# Out:
# 0     Y
# 1     N
# 2     N
# 3     Y
# 4     Y
# 5     Y
# 7     N
# 9     Y
# 11    Y
# 12    Y
# 13    Y
# 14    N
# 15    N
# 16    Y
# 17    Y
# 19    Y
# Name: Paying Customer, dtype: object

# %%
cd['Do_Not_Contact']=cd['Do_Not_Contact'].str.replace('Y','Yes').str.replace('N','No')
cd['Do_Not_Contact']
# Out:
# 0       Noo
# 1     Yeses
# 2       NaN
# 3       Yes
# 4       Noo
# 5     Yeses
# 7       Noo
# 9       Noo
# 11      NaN
# 12       No
# 13      Noo
# 14      Noo
# 15       No
# 16      Noo
# 17      NaN
# 19       No
# Name: Do_Not_Contact, dtype: object

# %%
cd.drop(columns='Not_Useful_Column',inplace=True)

# %%
cd
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 7         1008   Sherlock      Holmes   8766783469
# 9         1010      Peter      Parker   1235455421
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent   7066950392
# 19        1020     Anakin   Skywalker   8766783469
#
#                                   Address Paying Customer Do_Not_Contact  \
# ...
